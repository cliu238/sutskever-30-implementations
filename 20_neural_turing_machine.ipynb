# %% [markdown]
# 📅 **论文年份 (Year):2014 年**
# *Neural Turing Machines — Graves, Wayne, Danihelka*

# %% [markdown]
# # Paper 20: Neural Turing Machines(神经图灵机)
# ## Alex Graves, Greg Wayne, Ivo Danihelka (2014)
#
# ### External Memory with Differentiable Read/Write(具有可微分读/写的外部记忆)
#
# NTM augments neural networks with external memory that can be read from and written to via attention.
#
# NTM(神经图灵机)为神经网络增加了外部记忆(external memory),可以通过注意力(attention)机制对其进行读取和写入。

# %% [markdown]
# ## 📖 论文导读
#
# **🎯 这篇文章想解决什么问题(目的):** 普通神经网络就像一个只靠"脑子记"的人:所有信息都挤在网络内部的权重和隐藏状态里,记不了多少东西,也很难精确地保存和取用。而我们平时用的计算机之所以强大,是因为它有一块独立的内存,可以随时往里写、随时往外读。这篇论文想回答:能不能给神经网络也配上这样一块"外部记事本",让它像图灵机一样,学会自己读写记忆,从而执行更复杂的算法类任务?
#
# **💡 主要贡献:** 论文提出了神经图灵机(NTM):一个由"控制器"(神经网络)和"记忆矩阵"(外部内存)组成的系统。关键突破在于,读和写这两个原本"非此即彼"的离散操作,被设计成了可微分的软操作——每次读写不是只碰一个格子,而是按注意力权重"轻重不同地"碰所有格子。这样整个系统就能用普通的梯度下降端到端训练,让网络自己学会怎么用内存。
#
# **🔧 方法:** 控制器每一步通过"读头"和"写头"与记忆交互,寻址方式有两种:按内容找(拿一个查询向量去和内存各行比相似度,像按关键词搜索笔记)和按位置找(在上一次的位置上前后移动,像顺着页码翻本子)。写入则拆成"先擦除、再添加"两步。论文用复制、重复复制、联想回忆等小任务证明:NTM 能学到类似程序的解法,并能推广到比训练时更长的序列。
#
# **🌟 意义:** NTM 是"记忆增强神经网络"这一方向的开山之作,它把注意力机制用作可微分的寻址工具,这一思想直接启发了后来的可微分神经计算机(DNC),也与 Transformer 中"用注意力读取信息"的理念一脉相承。在这份阅读清单里,它代表了一个重要命题:神经网络不只是模式识别器,还可以学习算法本身——这正是通往更通用智能的一条思路。

# %% [markdown]
# ## 🎯 核心结论 (Key Takeaways)
#
# - **给神经网络配一块"外部记事本"是可行的**:NTM 把"控制器(神经网络)+ 记忆矩阵 + 读写头"组成一个系统,读写不再是非此即彼的离散操作,而是按注意力权重"轻重不同地"触碰所有格子,因此整个系统可微,能用普通的梯度下降端到端训练。
#
# - **NTM 学到的是"程序"而不是死记硬背**:论文在复制、重复复制、联想回忆等任务上证明,NTM 能学到类似算法的解法,并能推广到比训练时更长的序列——这正是它明显优于 LSTM 的地方(LSTM 把信息挤在隐藏状态里,序列一变长就崩)。
#
# - **两种寻址方式互补**:按内容找(拿 key 和每个记忆格子比余弦相似度,像按关键词搜索笔记)和按位置找(在上次位置上移动,像顺着页码翻本子);本 notebook 逐步实现并画出了完整流水线——内容寻址 → 门控插值 → 卷积移位 → 锐化,可以直观看到注意力分布如何一步步被调整和聚焦。
#
# - **写入 = 先擦除、再添加**:两个都是可微操作,组合起来实现对记忆的选择性修改;notebook 的复制任务演示中,4 个 one-hot 向量被依次写进 8×4 的记忆矩阵,记忆热力图像被逐渐"写上字",写入注意力热力图则显示每一步权重集中落在哪些格子上(注意:该演示用随机向量模拟控制器输出,展示的是机制而非训练效果)。
#
# - **代价与局限**:每次读写都要对整块记忆做注意力计算,开销大、难训练、记忆容量固定——这些短板直接催生了后续的可微分神经计算机(DNC)等改进。
#
# - **一句话带走**:注意力不仅能"看",还能当作可微分的内存地址来用——NTM 证明了神经网络可以学习算法本身,是记忆增强神经网络方向的开山之作,其"用注意力读取信息"的思想与 Transformer 一脉相承。

# %% [markdown]
# ## 🤯 反常识的发现 (Counterintuitive Findings)
#
# - **常识认为**"读内存第 3 格"这种指定地址的操作是离散的、非黑即白的,根本没法求导,梯度下降碰都碰不了。**但这篇论文发现**只要换个思路——每次不是只读一个格子,而是按注意力权重把所有格子都"模糊地"读一遍再加权求和——离散的寻址就变成了平滑可微的软操作。本 notebook 的 `Memory.read/write` 和寻址流水线(内容寻址 → 门控插值 → 卷积移位 → 锐化)正是这一招的逐步拆解:你能在图里看到注意力分布如何被一步步调整、聚焦。
#
# - **常识认为**神经网络学到的是"输入到输出的映射",训练时见过多长的序列,就只能应付多长的序列。**但论文实验发现** NTM 在复制、重复复制等任务上学会的是"算法"本身(先依次写入、再依次读出),所以能直接泛化到比训练时长得多的序列——而 LSTM 把信息全挤在隐藏状态里,序列一变长就崩。学会"程序"而不是死记"答案",这正是外部记忆带来的质变。
#
# - **常识认为**"写入"就是简单地把新值盖上去。**但 NTM 把写入拆成"先擦除、再添加"两个可微的步骤**——就像先用橡皮擦掉旧字再写新字,而且擦和写都可以只"部分地"进行。notebook 的复制任务演示里,4 个 one-hot 向量写进 8×4 记忆矩阵时,记忆热力图像被逐渐"写上字",写入注意力热力图显示每步权重落在哪些格子上——正是这套机制在起作用。
#
# - **常识认为**图灵机(磁带 + 读写头)是理论计算机科学的抽象玩具,和靠梯度训练的神经网络是两个世界。**但这篇论文发现**"神经网络控制器 + 外部记忆矩阵 + 注意力读写头"拼起来,约等于一台**可以用梯度下降训练的图灵机**:程序不是人写的,而是网络自己从数据里学出来的。这个组合后来催生了整个"记忆增强神经网络"方向。

# %% [markdown]
# #### 💻 代码解读
#
# **做什么:** 导入本笔记本需要的工具库,并固定随机种子,保证每次运行结果一致。
#
# **怎么做:**
# - 导入 `numpy`(数值计算库,用来做矩阵和向量运算)和 `matplotlib.pyplot`(画图库)。
# - 调用 `np.random.seed(42)` 固定随机数种子,就像掷骰子前先设定好点数顺序,后面所有随机初始化每次运行都相同,方便复现实验。

# %%
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(42)

# %% [markdown]
# ## External Memory Matrix(外部记忆矩阵)

# %% [markdown]
# #### 💻 代码解读
#
# **做什么:** 定义 NTM 的"外部记忆本"——`Memory` 类,本质是一个 N 行 M 列的矩阵,支持带注意力权重的读和写。
#
# **怎么做:**
# - `__init__` 创建一个 `num_slots × slot_size` 的矩阵(8 个格子,每格 4 维),用很小的随机数初始化,好比一本几乎空白的笔记本。
# - `read(weights)` 用注意力权重对所有记忆行做加权求和(`np.dot(weights, self.memory)`),相当于"每一页都瞄一眼,越重要的页看得越仔细",最后汇总成一个向量。
# - `write(weights, erase_vector, add_vector)` 分两步写入:先"擦除"——用 `np.outer(weights, erase_vector)` 按位置把旧内容部分擦掉;再"添加"——把新内容按权重叠加上去,就像先用橡皮擦再写新字。
# - `get_memory()` 返回记忆矩阵的副本;最后实例化一个 8×4 的 `memory` 并打印它的形状做检验。

# %%
class Memory:
    def __init__(self, num_slots, slot_size):
        """
        External memory bank
        
        num_slots: Number of memory locations (N)
        slot_size: Size of each memory vector (M)
        """
        self.num_slots = num_slots
        self.slot_size = slot_size
        
        # Initialize memory to small random values
        # 记忆矩阵M,形状(N, M):N个槽位,每个槽位存一个M维向量,类似一块可微分的"内存条"
        self.memory = np.random.randn(num_slots, slot_size) * 0.01
    
    def read(self, weights):
        """
        Read from memory using attention weights
        
        weights: (num_slots,) attention distribution
        Returns: (slot_size,) weighted combination of memory rows
        """
        # 软读取:所有槽位的加权平均而非取单个槽位,这样对权重可微、能用梯度训练
        # 形状:(N,) @ (N, M) -> (M,)
        return np.dot(weights, self.memory)
    
    def write(self, weights, erase_vector, add_vector):
        """
        Write to memory using erase and add operations
        
        weights: (num_slots,) where to write
        erase_vector: (slot_size,) what to erase
        add_vector: (slot_size,) what to add
        """
        # Erase: M_t = M_{t-1} * (1 - w_t ⊗ e_t)
        # 外积得到(N, M)的擦除掩码:第i行=weights[i]*erase_vector,权重越大擦得越多
        erase = np.outer(weights, erase_vector)
        self.memory = self.memory * (1 - erase)
        
        # Add: M_t = M_t + w_t ⊗ a_t
        # 写入分两步"先擦后加",模拟可微分版的内存覆写操作
        add = np.outer(weights, add_vector)
        self.memory = self.memory + add
    
    def get_memory(self):
        return self.memory.copy()

# Test memory
memory = Memory(num_slots=8, slot_size=4)
print(f"Memory initialized: {memory.num_slots} slots × {memory.slot_size} dimensions")
print(f"Memory shape: {memory.memory.shape}")

# %% [markdown]
# ## Content-Based Addressing(基于内容的寻址)
#
# Attend to memory locations based on content similarity
#
# 根据内容相似度对记忆位置进行注意力分配

# %% [markdown]
# #### 💻 代码解读
#
# **做什么:** 实现"按内容找位置"的寻址方式:给一个查询向量 key,算出记忆中每个格子和它有多像,越像的格子分到越高的注意力权重。
#
# **怎么做:**
# - `cosine_similarity(u, v)` 计算两个向量的余弦相似度(方向越接近越相似),分母加 `1e-8` 防止除零。
# - `softmax(x, beta)` 把一组分数变成总和为 1 的概率分布,`beta` 是"锐化旋钮":beta 越大,注意力越集中在最高分上。
# - `content_addressing(memory, key, beta)` 把 key 和记忆矩阵每一行逐个算相似度,再用 softmax 归一化,得到 8 个格子的注意力权重——好比拿着一张照片在相册里找最像的那张。
# - 最后用随机 key 和 `beta=2.0` 做测试,打印权重(总和应为 1),并用 `plt.bar` 画柱状图展示各记忆格子分到的注意力。

# %%
def cosine_similarity(u, v):
    """Cosine similarity between vectors"""
    # 余弦相似度只看方向不看长度;分母加1e-8防止除零
    return np.dot(u, v) / (np.linalg.norm(u) * np.linalg.norm(v) + 1e-8)

def softmax(x, beta=1.0):
    """Softmax with temperature beta"""
    # beta是"温度倒数":beta越大分布越尖锐,越接近one-hot
    x = beta * x
    # 减去最大值防止exp上溢,结果在数学上完全等价
    exp_x = np.exp(x - np.max(x))
    return exp_x / np.sum(exp_x)

def content_addressing(memory, key, beta):
    """
    Content-based addressing
    
    memory: (num_slots, slot_size)
    key: (slot_size,) query vector
    beta: sharpness parameter (> 0)
    
    Returns: (num_slots,) attention weights
    """
    # Compute cosine similarity with each memory row
    # 内容寻址:用key和每个槽位比相似度,"按内容找位置",类似字典按值查询
    similarities = np.array([
        cosine_similarity(key, memory[i]) 
        for i in range(len(memory))
    ])
    
    # Apply softmax with sharpness
    # softmax把相似度归一化成和为1的注意力分布,对应论文式(5)
    weights = softmax(similarities, beta=beta)
    
    return weights

# Test content addressing
key = np.random.randn(memory.slot_size)
beta = 2.0

weights = content_addressing(memory.memory, key, beta)
print(f"\nContent-based addressing:")
print(f"Key shape: {key.shape}")
print(f"Attention weights: {weights}")
print(f"Sum of weights: {weights.sum():.4f}")

# Visualize
plt.figure(figsize=(10, 4))
plt.bar(range(len(weights)), weights)
plt.xlabel('Memory Slot')
plt.ylabel('Attention Weight')
plt.title('Content-Based Addressing Weights')
plt.show()

# %% [markdown]
# ## Location-Based Addressing(基于位置的寻址)
#
# Shift attention based on relative positions (for sequential access)
#
# 基于相对位置移动注意力(用于顺序访问)

# %% [markdown]
# #### 💻 代码解读
#
# **做什么:** 实现"按位置找地址"的三个操作——门控插值、卷积移位、锐化,并把完整寻址流水线的每一步画出来对比。
#
# **怎么做:**
# - `interpolation(weights_content, weights_prev, g)`:用门 g(0 到 1)在"内容权重"和"上一步权重"之间调配,g=1 全信内容,g=0 全用旧位置,像新旧信息之间的混音旋钮。
# - `convolutional_shift(weights, shift_weights)`:用 `np.roll` 把注意力整体向左/不动/向右挪一格,再按移位分布加权混合——相当于"从当前页往前或往后翻一页"。
# - `sharpening(weights, gamma)`:把权重取 gamma 次方再归一化,gamma 越大分布越尖锐,防止移位后注意力变得模糊。
# - 测试部分依次执行完整流水线:内容寻址 → 插值(g=0.7 偏向内容)→ 移位(shift_weights 中 0.8 概率不动)→ 锐化(gamma=2.0)。
# - 最后用 2×3 的子图画出每个阶段的权重柱状图:旧权重、内容权重、门控后、移位分布、移位后、锐化后。

# %%
def interpolation(weights_content, weights_prev, g):
    """
    Interpolate between content and previous weights
    
    g: gate in [0, 1]
      g=1: use only content weights
      g=0: use only previous weights
    """
    # 门控插值:g像一个可学习的开关,决定"按内容找"还是"沿用上一步的位置"
    return g * weights_content + (1 - g) * weights_prev

def convolutional_shift(weights, shift_weights):
    """
    Rotate attention weights by shift distribution
    
    shift_weights: distribution over [-1, 0, +1] shifts
    """
    num_slots = len(weights)
    shifted = np.zeros_like(weights)
    
    # Apply each shift
    # 循环卷积实现位置寻址:注意力可整体左移/右移,让NTM能像磁头一样顺序移动
    for shift_idx, shift_amount in enumerate([-1, 0, 1]):
        # np.roll循环移位,末尾会绕回开头(把内存当成环形磁带)
        rolled = np.roll(weights, shift_amount)
        # 按移位分布加权求和,相当于对权重向量做一次卷积
        shifted += shift_weights[shift_idx] * rolled
    
    return shifted

def sharpening(weights, gamma):
    """
    Sharpen attention distribution
    
    gamma >= 1: larger values = sharper distribution
    """
    # 逐元素取gamma次幂后重新归一化:抵消卷积移位带来的注意力"模糊化"
    weights = weights ** gamma
    return weights / (np.sum(weights) + 1e-8)

# Test location-based operations
# 下面按论文图2的顺序演示完整寻址流水线:内容寻址→门控插值→移位→锐化
weights_prev = np.array([0.05, 0.1, 0.2, 0.3, 0.2, 0.1, 0.04, 0.01])
weights_content = content_addressing(memory.memory, key, beta=2.0)

# Interpolation
g = 0.7  # Favor content
weights_gated = interpolation(weights_content, weights_prev, g)

# Shift
shift_weights = np.array([0.1, 0.8, 0.1])  # Mostly stay, little shift
weights_shifted = convolutional_shift(weights_gated, shift_weights)

# Sharpen
gamma = 2.0
weights_sharp = sharpening(weights_shifted, gamma)

# Visualize addressing pipeline
fig, axes = plt.subplots(2, 3, figsize=(15, 8))

axes[0, 0].bar(range(len(weights_prev)), weights_prev)
axes[0, 0].set_title('Previous Weights')
axes[0, 0].set_ylim(0, 0.5)

axes[0, 1].bar(range(len(weights_content)), weights_content)
axes[0, 1].set_title('Content Weights')
axes[0, 1].set_ylim(0, 0.5)

axes[0, 2].bar(range(len(weights_gated)), weights_gated)
axes[0, 2].set_title(f'Gated (g={g})')
axes[0, 2].set_ylim(0, 0.5)

axes[1, 0].bar(range(len(shift_weights)), shift_weights, color='orange')
axes[1, 0].set_title('Shift Distribution')
axes[1, 0].set_xticks([0, 1, 2])
axes[1, 0].set_xticklabels(['-1', '0', '+1'])

axes[1, 1].bar(range(len(weights_shifted)), weights_shifted, color='green')
axes[1, 1].set_title('After Shift')
axes[1, 1].set_ylim(0, 0.5)

axes[1, 2].bar(range(len(weights_sharp)), weights_sharp, color='red')
axes[1, 2].set_title(f'Sharpened (γ={gamma})')
axes[1, 2].set_ylim(0, 0.5)

plt.tight_layout()
plt.show()

print(f"\nAddressing pipeline complete!")

# %% [markdown]
# ## Complete NTM Head (Read/Write)(完整的 NTM 读/写头)

# %% [markdown]
# #### 💻 代码解读
#
# **做什么:** 定义完整的 NTM 读写头 `NTMHead` 类,把前面的寻址操作串成一条流水线,所有寻址参数都由控制器(神经网络)的输出动态生成。
#
# **怎么做:**
# - `__init__` 初始化一组权重矩阵(`W_key`、`W_beta`、`W_g`、`W_shift`、`W_gamma`、`W_erase`、`W_add`),负责把控制器输出"翻译"成各种寻址参数;`weights_prev` 初始为均匀分布(一开始对每个格子一视同仁)。
# - `address(memory, controller_output)` 是核心:从控制器输出算出 key(tanh)、beta(exp 保证为正)、门 g(sigmoid 压到 0~1)、移位分布(softmax)、gamma(exp+1 保证不小于 1),然后依次执行内容寻址 → 插值 → 卷积移位 → 锐化,得到最终注意力权重,并保存为下一步的 `weights_prev`。
# - `read` 直接调用记忆的加权读取;`write` 用 sigmoid 生成擦除向量、tanh 生成添加向量,再交给 `memory.write` 完成"先擦后写"。
# - 整体好比一个机械臂:控制器发指令,读写头把指令翻译成"翻到哪一页、擦掉什么、写上什么"。

# %%
class NTMHead:
    def __init__(self, memory_slots, memory_size, controller_size):
        self.memory_slots = memory_slots
        self.memory_size = memory_size
        
        # Parameters produced by controller
        # 读写头的所有寻址参数(key、beta、g、shift、gamma)都由控制器输出经线性层生成
        # Key for content addressing
        self.W_key = np.random.randn(memory_size, controller_size) * 0.1
        
        # Strength (beta)
        self.W_beta = np.random.randn(1, controller_size) * 0.1
        
        # Gate (g)
        self.W_g = np.random.randn(1, controller_size) * 0.1
        
        # Shift weights
        self.W_shift = np.random.randn(3, controller_size) * 0.1
        
        # Sharpening (gamma)
        self.W_gamma = np.random.randn(1, controller_size) * 0.1
        
        # For write head: erase and add vectors
        self.W_erase = np.random.randn(memory_size, controller_size) * 0.1
        self.W_add = np.random.randn(memory_size, controller_size) * 0.1
        
        # Previous weights
        # 初始化为均匀分布;上一步的权重是插值门g的另一路输入,是NTM的"位置记忆"
        self.weights_prev = np.ones(memory_slots) / memory_slots
    
    def address(self, memory, controller_output):
        """
        Compute addressing weights from controller output
        """
        # Content addressing
        # tanh把key压到[-1,1],形状:(M, C) @ (C,) -> (M,)
        key = np.tanh(np.dot(self.W_key, controller_output))
        # 用exp保证beta>0(锐度参数必须为正),加1e-4避免恰好为0
        beta = np.exp(np.dot(self.W_beta, controller_output))[0] + 1e-4
        weights_content = content_addressing(memory, key, beta)
        
        # Interpolation
        # sigmoid把门g压到(0,1),满足插值系数的取值要求
        g = 1 / (1 + np.exp(-np.dot(self.W_g, controller_output)))[0]  # sigmoid
        weights_gated = interpolation(weights_content, self.weights_prev, g)
        
        # Shift
        shift_logits = np.dot(self.W_shift, controller_output)
        shift_weights = softmax(shift_logits)
        weights_shifted = convolutional_shift(weights_gated, shift_weights)
        
        # Sharpen
        # exp(...)+1保证gamma>=1:幂次至少为1才不会把分布反向"摊平"
        gamma = np.exp(np.dot(self.W_gamma, controller_output))[0] + 1.0
        weights = sharpening(weights_shifted, gamma)
        
        # 保存本步权重,供下一时间步做插值(实现跨时间步的位置追踪)
        self.weights_prev = weights
        return weights
    
    def read(self, memory, weights):
        """Read from memory"""
        return memory.read(weights)
    
    def write(self, memory, weights, controller_output):
        """Write to memory"""
        # 擦除向量用sigmoid限制在(0,1):每个维度擦除的比例;加法向量用tanh限制在(-1,1)
        erase = 1 / (1 + np.exp(-np.dot(self.W_erase, controller_output)))  # sigmoid
        add = np.tanh(np.dot(self.W_add, controller_output))
        memory.write(weights, erase, add)

print("NTM Head created with full addressing mechanism")

# %% [markdown]
# ## Test Task: Copy Sequence(测试任务:复制序列)
#
# Classic NTM task: copy a sequence from input to output
#
# 经典的 NTM 任务:将一个序列从输入复制到输出

# %% [markdown]
# #### 💻 代码解读
#
# **做什么:** 用一个简化的"复制任务"演示 NTM 的写入过程:把 4 个 one-hot 向量依次写进记忆,并把记忆的变化和写入注意力可视化出来。
#
# **怎么做:**
# - 新建 8×4 的 `Memory` 和一个 `NTMHead`(控制器维度 16),准备由 4 个 one-hot 向量组成的 `sequence`。
# - 写入循环:每一步用随机向量模拟控制器输出(仅作演示,没有真正训练),调用 `head.address` 算出写入位置权重,再用 `head.write` 写入记忆;同时把每步的记忆快照存进 `memory_states`、权重存进 `write_weights_history`。
# - 第一组图:用 `imshow` 画出初始记忆和每次写入后的记忆热力图,可以看到记忆矩阵像被逐渐"写上字"一样发生变化。
# - 第二组图:把写入权重历史转置后画成热力图,横轴是写入步骤、纵轴是记忆格子,展示每一步的注意力"落"在了哪些格子上;最后打印共写入了几个条目。

# %%
# Simple copy task
memory = Memory(num_slots=8, slot_size=4)
controller_size = 16
head = NTMHead(memory.num_slots, memory.slot_size, controller_size)

# Input sequence
sequence = [
    np.array([1, 0, 0, 0]),
    np.array([0, 1, 0, 0]),
    np.array([0, 0, 1, 0]),
    np.array([0, 0, 0, 1]),
]

# Write phase: store sequence in memory
memory_states = [memory.get_memory()]
write_weights_history = []

# 演示复制任务的写入阶段:逐个时间步把序列写进外部记忆
for i, item in enumerate(sequence):
    # Simulate controller output (random for demo)
    # 真实NTM中控制器(如LSTM)由输入item计算输出,这里用随机向量代替以只演示寻址/写入机制
    controller_out = np.random.randn(controller_size)
    
    # Get write weights
    # 完整寻址流水线:内容寻址→插值→移位→锐化,得到写入位置分布
    weights = head.address(memory.memory, controller_out)
    write_weights_history.append(weights)
    
    # Write to memory
    head.write(memory, weights, controller_out)
    memory_states.append(memory.get_memory())

# Visualize write process
fig, axes = plt.subplots(1, len(sequence) + 1, figsize=(16, 4))

# Initial memory
axes[0].imshow(memory_states[0], cmap='RdBu', aspect='auto')
axes[0].set_title('Initial Memory')
axes[0].set_ylabel('Memory Slot')
axes[0].set_xlabel('Dimension')

# After each write
for i in range(len(sequence)):
    axes[i+1].imshow(memory_states[i+1], cmap='RdBu', aspect='auto')
    axes[i+1].set_title(f'After Write {i+1}')
    axes[i+1].set_xlabel('Dimension')

plt.tight_layout()
plt.suptitle('Memory Evolution During Write', y=1.05)
plt.show()

# Show write attention patterns
# 转置后形状(num_slots, num_steps):行=槽位、列=时间步,便于画注意力热图
write_weights = np.array(write_weights_history).T

plt.figure(figsize=(10, 6))
plt.imshow(write_weights, cmap='viridis', aspect='auto')
plt.colorbar(label='Write Weight')
plt.xlabel('Write Step')
plt.ylabel('Memory Slot')
plt.title('Write Attention Patterns')
plt.show()

print(f"\nWrote {len(sequence)} items to memory")

# %% [markdown]
# ## Key Takeaways(要点总结)
#
# ### NTM Architecture:
# 1. **Controller**: Neural network (LSTM/FF) that produces control signals
# 2. **Memory Matrix**: External memory (N × M)
# 3. **Read Heads**: Attention-based reading
# 4. **Write Heads**: Attention-based writing with erase + add
#
# ### Addressing Mechanisms:
# 1. **Content-Based**: Similarity to memory contents
# 2. **Location-Based**: Relative shifts (sequential access)
# 3. **Combination**: Interpolate between content and location
#
# ### Addressing Pipeline:
# ```
# Content Addressing → Interpolation → Shift → Sharpening
# ```
#
# ### Write Operations:
# - **Erase**: M_t = M_{t-1} ⊙ (1 - w ⊗ e)
# - **Add**: M_t = M_t + (w ⊗ a)
# - Combines to allow selective modification
#
# ### Capabilities:
# - Copy and recall sequences
# - Learn algorithms (sorting, copying, etc.)
# - Generalize to longer sequences
# - Differentiable memory access
#
# ### Limitations:
# - Computationally expensive (attention over all memory)
# - Difficult to train
# - Memory size fixed
#
# ### Impact:
# - Inspired differentiable memory research
# - Led to: Differentiable Neural Computer (DNC), Memory Networks
# - Showed neural networks can learn algorithms
# - Precursor to modern external memory systems
#
# ### NTM 架构:
# 1. **控制器(Controller)**:产生控制信号的神经网络(LSTM/前馈网络)
# 2. **记忆矩阵(Memory Matrix)**:外部记忆(N × M)
# 3. **读头(Read Heads)**:基于注意力的读取
# 4. **写头(Write Heads)**:基于注意力的写入,包含擦除(erase)+ 添加(add)操作
#
# ### 寻址机制:
# 1. **基于内容(Content-Based)**:与记忆内容的相似度
# 2. **基于位置(Location-Based)**:相对移位(顺序访问)
# 3. **组合(Combination)**:在内容寻址和位置寻址之间插值
#
# ### 寻址流程:
# ```
# 内容寻址(Content Addressing) → 插值(Interpolation) → 移位(Shift) → 锐化(Sharpening)
# ```
#
# ### 写操作:
# - **擦除(Erase)**:M_t = M_{t-1} ⊙ (1 - w ⊗ e)
# - **添加(Add)**:M_t = M_t + (w ⊗ a)
# - 二者结合可实现选择性修改
#
# ### 能力:
# - 复制和回忆序列
# - 学习算法(排序、复制等)
# - 泛化到更长的序列
# - 可微分的记忆访问
#
# ### 局限性:
# - 计算开销大(需要对整个记忆做注意力计算)
# - 难以训练
# - 记忆容量固定
#
# ### 影响:
# - 启发了可微分记忆(differentiable memory)研究
# - 催生了:可微分神经计算机(Differentiable Neural Computer, DNC)、记忆网络(Memory Networks)
# - 证明了神经网络可以学习算法
# - 现代外部记忆系统的先驱
